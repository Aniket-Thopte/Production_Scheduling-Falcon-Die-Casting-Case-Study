# %%
import pandas as pd
import itertools
from gurobipy import *
production = pd.read_excel("data.xlsx", header = 0, index_col=0, sheet_name = "production")
setup = pd.read_excel("data.xlsx", header = 0, index_col=0, sheet_name = "setup")
demand = pd.read_excel("data.xlsx", header = 0, index_col=0, sheet_name = "demand")

# Get the machines and parts from the setup sheet in excel
parts = list(setup.columns)
machines = list(setup.index)

print(parts)
# this is the working time in a week
combine_list = []
for r in itertools.product(machines, parts):
    combine_list.append(r[0]+ "_" +r[1]) 
# combine_list
# create dictionary for objective coefficient
setup_cost = {}
for v in combine_list:
    first = v.split("_")[0]
    second = v.split("_")[1]
    setup_cost[v] = setup.loc[first, second]


# maximum regular working hours per week
regular_hours_machine = {}
for name in machines:
    regular_hours_machine[name] = 120

# maximum overtime hours per week
overtime_hours = {}
for name in machines:
    overtime_hours[name] = 48



# Demand of each part
constraint_left_p_eq = {}
# example {"Part1":{"Machine1_Part1_Production":24, ...}}
for p in parts:
    production_co = {}
    for v in combine_list:
        first = v.split("_")[0]
        second = v.split("_")[1]
        if second ==p:
            production_co[v] = production.loc[first, second]
        else:
            production_co[v] = 0
    constraint_left_p_eq[p] = production_co
# constraint_left_p_eq

# setup time for each machine
setup_time_machine = {}
# example {"Machine1":{"Machine1_Part1_Production":8, ...}}
for m in machines:
    setup_dic = {}
    for v in combine_list:
        first = v.split("_")[0]
        second = v.split("_")[1]
        if first == m:
            setup_dic[v] = setup.loc[first, second]
        else:
            setup_dic[v] = 0
    setup_time_machine[m] = setup_dic
    

# production time for each machine
production_time_machine = {}
# example {"Machine1":{"Machine1_Part1_Production":24, ...}}
for m in machines:
    production_dic = {}
    for v in combine_list:
        first = v.split("_")[0]
        second = v.split("_")[1]
        if first == m:
            production_dic[v] = 1
        else:
            production_dic[v] = 0
    production_time_machine[m] = production_dic
# production_time_machine


# In[8]:


def optimize_model(week):
    # set up constraints name
    # Get demand for each part from demand table for week
    constraint_right_eq = {}
    for name in parts:
        constraint_right_eq[name] = demand.loc[week, name]

    m=Model()

    overtime_production_levels = m.addVars(combine_list, name="overtime")
    setup_levels = m.addVars(combine_list, name="setup", vtype = GRB.BINARY)
    regular_production_levels = m.addVars(combine_list, name="regular")
    
    overtime_leq = m.addConstrs((quicksum(production_time_machine[m][vp]*overtime_production_levels[vp] for vp in combine_list)
                                           <= overtime_hours[m] for m in machines), name="overtime_leq");

    
    regular_leq = m.addConstrs((quicksum(production_time_machine[m][vp]*regular_production_levels[vp] for vp in combine_list) + quicksum(setup_time_machine[m][vs]*setup_levels[vs] for vs in combine_list) 
                                           <= regular_hours_machine[m] for m in machines), name="regular_leq");
    
    eq_constraints_set = m.addConstrs((quicksum(setup_levels[v]*constraint_left_p_eq[p][v]*regular_production_levels[v] for v in combine_list) + quicksum(setup_levels[v]*constraint_left_p_eq[p][v]*overtime_production_levels[v] for v in combine_list)
                                           == constraint_right_eq[p] for p in parts ), name="eq_constraints"); 
    
    obj = quicksum(overtime_production_levels[vp] for vp in combine_list)
    m.update()
    m.setObjective(obj, GRB.MINIMIZE)
    m.update()
    m.optimize()
    cost = 0
    regular_hours = 0
    for variable in m.getVars():
        if variable.x != 0:
            name = variable.varName
            n1 = name.split("[")[0]
            n2 = name.split("[")[-1][:-1]
            if n1 == "setup":
                value = setup_cost[n2]*variable.x
                cost += setup_cost[n2]*variable.x*100
                regular_hours += setup_cost[n2]*variable.x
            elif n1 == "regular":
                value = variable.x
                cost += 100*variable.x
                regular_hours += variable.x
            else:
                value = variable.x
                cost += 150*variable.x
            print('%s %g' % (variable.varName, value))  

    print('Obj: %g' % m.ObjVal)
    print('total cost1: %g' % cost)
    print("regular hours: %g" % regular_hours)
    m.reset()


optimize_model(1)


optimize_model(2)


optimize_model(3)


optimize_model(4)


optimize_model(5)


optimize_model(6)


optimize_model(7)


optimize_model(8)


optimize_model(9)


optimize_model(10)


# PLease uncomment if needed. But the solution for this week is infeasible and hence the code might break.
# optimize_model(11)


optimize_model(12)
# Out:
# ['Part1', 'Part2', 'Part3', 'Part4', 'Part5']
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model fingerprint: 0xc34d78de
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 4e+03]
# Presolve removed 0 rows and 47 columns
# Presolve time: 0.00s
# Presolved: 68 rows, 46 columns, 173 nonzeros
# Variable types: 37 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 1.120894e+02, 17 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  112.08943    0    6          -  112.08943      -     -    0s
# H    0     0                     128.0767288  112.08943  12.5%     -    0s
# H    0     0                     119.7644578  112.08943  6.41%     -    0s
#      0     0  119.76446    0    1  119.76446  119.76446  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 5
#   Flow cover: 2
#   Relax-and-lift: 3
#
# Explored 1 nodes (26 simplex iterations) in 0.06 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 119.764 128.077
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.197644577645e+02, best bound 1.197644577645e+02, gap 0.0000%
# overtime[Machine1_Part1] 48
# overtime[Machine2_Part1] 0.168498
# overtime[Machine3_Part2] 23.596
# overtime[Machine4_Part2] 41.3333
# overtime[Machine4_Part3] 6.66667
# setup[Machine1_Part1] 8
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part2] 8
# setup[Machine4_Part3] 12
# setup[Machine5_Part5] 20
# regular[Machine1_Part1] 1.4359
# regular[Machine1_Part4] 102.564
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part3] 100
# regular[Machine5_Part5] 93.3333
# Obj: 119.764
# total cost1: 77298
# regular hours: 593.333
# Discarded solution information
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model fingerprint: 0xb059310a
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 4e+03]
# Presolve removed 0 rows and 47 columns
# Presolve time: 0.00s
# Presolved: 68 rows, 46 columns, 173 nonzeros
# Variable types: 37 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 8.216657e+01, 19 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   82.16657    0    6          -   82.16657      -     -    0s
# H    0     0                     102.8144911   82.16657  20.1%     -    0s
# H    0     0                      92.3318903   82.16657  11.0%     -    0s
#      0     0   92.33189    0    5   92.33189   92.33189  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 1
#   Implied bound: 4
#   MIR: 1
#   Flow cover: 3
#   Relax-and-lift: 1
#
# Explored 1 nodes (28 simplex iterations) in 0.06 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 92.3319 102.814
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.233189033189e+01, best bound 9.233189033189e+01, gap 0.0000%
# overtime[Machine2_Part1] 32.8571
# overtime[Machine3_Part2] 11.4747
# overtime[Machine4_Part2] 41.3333
# overtime[Machine4_Part3] 6.66667
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part2] 8
# setup[Machine4_Part3] 12
# setup[Machine5_Part5] 20
# regular[Machine1_Part4] 110.256
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part3] 100
# regular[Machine5_Part5] 93.3333
# Obj: 92.3319
# total cost1: 73008.8
# regular hours: 591.59
# Discarded solution information
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model fingerprint: 0x8dd1b654
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [2e+03, 4e+03]
# Presolve removed 0 rows and 47 columns
# Presolve time: 0.00s
# Presolved: 68 rows, 46 columns, 173 nonzeros
# Variable types: 37 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 2.392348e+01, 15 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   23.92348    0    3          -   23.92348      -     -    0s
# H    0     0                      32.7057110   23.92348  26.9%     -    0s
# H    0     0                      25.7057110   23.92348  6.93%     -    0s
#      0     0     cutoff    0        25.70571   25.70571  0.00%     -    0s
#
# Cutting planes:
#   Relax-and-lift: 2
#
# Explored 1 nodes (16 simplex iterations) in 0.04 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 25.7057 32.7057
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.570571095571e+01, best bound 2.570571095571e+01, gap 0.0000%
# overtime[Machine1_Part4] 14.4936
# overtime[Machine3_Part2] 11.2121
# setup[Machine1_Part1] 8
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part3] 12
# setup[Machine5_Part5] 20
# regular[Machine1_Part1] 28.75
# regular[Machine1_Part4] 75.25
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part3] 106.667
# regular[Machine5_Part5] 100
# Obj: 25.7057
# total cost1: 63722.5
# regular hours: 598.667
# Discarded solution information
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model fingerprint: 0x6cee0778
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 4e+03]
# Presolve removed 0 rows and 47 columns
# Presolve time: 0.00s
# Presolved: 68 rows, 46 columns, 173 nonzeros
# Variable types: 37 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 8.860615e+01, 17 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   88.60615    0    6          -   88.60615      -     -    0s
# H    0     0                     102.1151904   88.60615  13.2%     -    0s
# H    0     0                     100.7818570   88.60615  12.1%     -    0s
# H    0     0                      93.7818570   88.60615  5.52%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Implied bound: 4
#   Flow cover: 1
#   RLT: 1
#   Relax-and-lift: 4
#
# Explored 1 nodes (17 simplex iterations) in 0.05 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 93.7819 100.782 102.115
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.378185703186e+01, best bound 9.378185703186e+01, gap 0.0000%
# overtime[Machine1_Part4] 22.1859
# overtime[Machine3_Part2] 23.596
# overtime[Machine4_Part2] 41.3333
# overtime[Machine4_Part3] 6.66667
# setup[Machine1_Part1] 8
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part2] 8
# setup[Machine4_Part3] 12
# setup[Machine5_Part5] 20
# regular[Machine1_Part1] 28.75
# regular[Machine1_Part4] 75.25
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part3] 100
# regular[Machine5_Part5] 93.3333
# Obj: 93.7819
# total cost1: 73400.6
# regular hours: 593.333
# Discarded solution information
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model fingerprint: 0x42615523
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 4e+03]
# Presolve removed 0 rows and 47 columns
# Presolve time: 0.00s
# Presolved: 68 rows, 46 columns, 173 nonzeros
# Variable types: 37 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 9.198051e+01, 18 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   91.98051    0    6          -   91.98051      -     -    0s
# H    0     0                     107.2433955   91.98051  14.2%     -    0s
# H    0     0                      98.9100622   91.98051  7.01%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Implied bound: 4
#   Flow cover: 1
#   Relax-and-lift: 5
#
# Explored 1 nodes (18 simplex iterations) in 0.05 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 98.9101 107.243
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.891006216006e+01, best bound 9.891006216006e+01, gap 0.0000%
# overtime[Machine1_Part4] 27.3141
# overtime[Machine3_Part2] 23.596
# overtime[Machine4_Part2] 41.3333
# overtime[Machine4_Part3] 6.66667
# setup[Machine1_Part1] 8
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part2] 8
# setup[Machine4_Part3] 12
# setup[Machine5_Part5] 20
# regular[Machine1_Part1] 28.75
# regular[Machine1_Part4] 75.25
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part3] 100
# regular[Machine5_Part5] 93.3333
# Obj: 98.9101
# total cost1: 74169.8
# regular hours: 593.333
# Discarded solution information
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model fingerprint: 0x3120e800
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 4e+03]
# Presolve removed 0 rows and 47 columns
# Presolve time: 0.00s
# Presolved: 68 rows, 46 columns, 173 nonzeros
# Variable types: 37 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 6.901568e+01, 17 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   69.01568    0    5          -   69.01568      -     -    0s
# H    0     0                      83.6036464   69.01568  17.4%     -    0s
# H    0     0                      75.8677156   69.01568  9.03%     -    0s
#      0     0     cutoff    0        75.86772   75.86772  0.00%     -    0s
#
# Cutting planes:
#   Implied bound: 2
#   MIR: 5
#   Flow cover: 3
#   Relax-and-lift: 2
#
# Explored 1 nodes (23 simplex iterations) in 0.04 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 75.8677 83.6036
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.586771561772e+01, best bound 7.586771561772e+01, gap 0.0000%
# overtime[Machine3_Part2] 41.5152
# overtime[Machine5_Part5] 34.3526
# setup[Machine1_Part1] 8
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part3] 12
# setup[Machine5_Part4] 8
# setup[Machine5_Part5] 20
# regular[Machine1_Part1] 49.5833
# regular[Machine1_Part4] 54.4167
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part3] 106.667
# regular[Machine5_Part4] 43.0192
# regular[Machine5_Part5] 48.9808
# Obj: 75.8677
# total cost1: 71246.8
# regular hours: 598.667
# Discarded solution information
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model fingerprint: 0x3560ef3c
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 4e+03]
# Presolve removed 0 rows and 47 columns
# Presolve time: 0.00s
# Presolved: 68 rows, 46 columns, 173 nonzeros
# Variable types: 37 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 6.873712e+01, 15 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   68.73712    0    3          -   68.73712      -     -    0s
# H    0     0                      76.3985181   68.73712  10.0%     -    0s
#      0     0     cutoff    0        76.39852   76.39852  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Implied bound: 1
#   MIR: 4
#   Flow cover: 4
#   RLT: 1
#
# Explored 1 nodes (19 simplex iterations) in 0.05 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 76.3985
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.639851814852e+01, best bound 7.639851814852e+01, gap 0.0000%
# overtime[Machine4_Part2] 35.5844
# overtime[Machine4_Part3] 1.33333
# overtime[Machine5_Part5] 39.4808
# setup[Machine1_Part1] 8
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part2] 8
# setup[Machine4_Part3] 12
# setup[Machine5_Part4] 8
# setup[Machine5_Part5] 20
# regular[Machine1_Part1] 49.5833
# regular[Machine1_Part4] 54.4167
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part3] 100
# regular[Machine5_Part4] 48.1474
# regular[Machine5_Part5] 43.8526
# Obj: 76.3985
# total cost1: 71459.8
# regular hours: 600
# Discarded solution information
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model fingerprint: 0xbd46a97d
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 4e+03]
# Presolve removed 0 rows and 47 columns
# Presolve time: 0.00s
# Presolved: 68 rows, 46 columns, 173 nonzeros
# Variable types: 37 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 1.114552e+02, 20 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  111.45518    0    5          -  111.45518      -     -    0s
# H    0     0                     129.7806915  111.45518  14.1%     -    0s
# H    0     0                     122.7806915  111.45518  9.22%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Implied bound: 2
#   MIR: 4
#   Flow cover: 4
#   Relax-and-lift: 1
#
# Explored 1 nodes (20 simplex iterations) in 0.04 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 122.781 129.781
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.227806915307e+02, best bound 1.227806915307e+02, gap 0.0000%
# overtime[Machine3_Part2] 38.5051
# overtime[Machine4_Part3] 48
# overtime[Machine5_Part5] 36.2756
# setup[Machine1_Part1] 8
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part2] 8
# setup[Machine4_Part3] 12
# setup[Machine5_Part4] 8
# setup[Machine5_Part5] 20
# regular[Machine1_Part1] 41.25
# regular[Machine1_Part4] 62.75
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part2] 49.3333
# regular[Machine4_Part3] 50.6667
# regular[Machine5_Part4] 44.9423
# regular[Machine5_Part5] 47.0577
# Obj: 122.781
# total cost1: 78417.1
# regular hours: 600
# Discarded solution information
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model fingerprint: 0xb675c8bc
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 5e+03]
# Presolve removed 1 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 45 columns, 170 nonzeros
# Variable types: 36 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 1.267085e+01, 15 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   12.67085    0    6          -   12.67085      -     -    0s
# H    0     0                      48.6891608   12.67085  74.0%     -    0s
# H    0     0                      31.0782868   17.84454  42.6%     -    0s
#      0     0   29.76652    0    7   31.07829   29.76652  4.22%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 2
#   Implied bound: 4
#   MIR: 9
#   Flow cover: 6
#   Relax-and-lift: 5
#
# Explored 1 nodes (26 simplex iterations) in 0.05 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 31.0783 48.6892
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.107828679257e+01, best bound 3.107828679257e+01, gap 0.0000%
# overtime[Machine3_Part5] 15.1111
# overtime[Machine4_Part2] 12.5826
# overtime[Machine5_Part4] 3.38462
# setup[Machine1_Part1] 8
# setup[Machine2_Part1] 10
# setup[Machine2_Part2] 8
# setup[Machine3_Part5] 24
# setup[Machine4_Part2] 8
# setup[Machine5_Part4] 8
# regular[Machine1_Part1] 112
# regular[Machine2_Part1] 29.1429
# regular[Machine2_Part2] 72.8571
# regular[Machine3_Part2] -5.21065e-13
# regular[Machine3_Part5] 96
# regular[Machine4_Part2] 112
# regular[Machine5_Part4] 112
# Obj: 31.0783
# total cost1: 64661.7
# regular hours: 600
# Discarded solution information
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model fingerprint: 0x9dd27d27
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 5e+03]
# Presolve removed 1 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 67 rows, 45 columns, 170 nonzeros
# Variable types: 36 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 0.000000e+00, 13 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    6          -    0.00000      -     -    0s
# H    0     0                      23.9088689    0.00000   100%     -    0s
#      0     0    5.98743    0    4   23.90887    5.98743  75.0%     -    0s
# H    0     0                      15.1111111    5.98743  60.4%     -    0s
#      0     0   15.11111    0    5   15.11111   15.11111  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Implied bound: 3
#   MIR: 2
#   Flow cover: 3
#   Relax-and-lift: 2
#
# Explored 1 nodes (29 simplex iterations) in 0.05 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 15.1111 23.9089
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.511111111111e+01, best bound 1.511111111111e+01, gap 0.0000%
# overtime[Machine3_Part5] 15.1111
# setup[Machine1_Part1] 8
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine2_Part2] 8
# setup[Machine3_Part5] 24
# setup[Machine4_Part2] 8
# setup[Machine5_Part4] 8
# regular[Machine1_Part1] 97.7924
# regular[Machine1_Part4] 3.38462
# regular[Machine2_Part1] 40.6182
# regular[Machine2_Part2] 61.3818
# regular[Machine3_Part5] 96
# regular[Machine4_Part2] 112
# regular[Machine5_Part4] 112
# Obj: 15.1111
# total cost1: 61984.4
# regular hours: 597.177
# Discarded solution information
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (win64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 10 rows, 75 columns and 60 nonzeros
# Model fingerprint: 0xb059310a
# Model has 5 quadratic constraints
# Variable types: 50 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   QMatrix range    [1e+01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e+01, 1e+02]
#   QRHS range       [3e+03, 4e+03]
# Presolve removed 0 rows and 47 columns
# Presolve time: 0.00s
# Presolved: 68 rows, 46 columns, 173 nonzeros
# Variable types: 37 continuous, 9 integer (9 binary)
#
# Root relaxation: objective 8.216657e+01, 19 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   82.16657    0    6          -   82.16657      -     -    0s
# H    0     0                     102.8144911   82.16657  20.1%     -    0s
# H    0     0                      92.3318903   82.16657  11.0%     -    0s
#      0     0   92.33189    0    5   92.33189   92.33189  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 1
#   Implied bound: 4
#   MIR: 1
#   Flow cover: 3
#   Relax-and-lift: 1
#
# Explored 1 nodes (28 simplex iterations) in 0.05 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 92.3319 102.814
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.233189033189e+01, best bound 9.233189033189e+01, gap 0.0000%
# overtime[Machine2_Part1] 32.8571
# overtime[Machine3_Part2] 11.4747
# overtime[Machine4_Part2] 41.3333
# overtime[Machine4_Part3] 6.66667
# setup[Machine1_Part4] 8
# setup[Machine2_Part1] 10
# setup[Machine3_Part2] 10
# setup[Machine4_Part2] 8
# setup[Machine4_Part3] 12
# setup[Machine5_Part5] 20
# regular[Machine1_Part4] 110.256
# regular[Machine2_Part1] 110
# regular[Machine3_Part2] 110
# regular[Machine4_Part3] 100
# regular[Machine5_Part5] 93.3333
# Obj: 92.3319
# total cost1: 73008.8
# regular hours: 591.59
# Discarded solution information
